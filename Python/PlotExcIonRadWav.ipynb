# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import os
plt.rcParams['ytick.right']  =plt.rcParams['xtick.top'] =True
xminorLocator=MultipleLocator(2)
#plt.rcParams['set_minor_locator']=xminorLocator
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["TimeNewroman"]})
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})
# It's also possible to use the reduced notation by directly setting font.family:
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "TimeNewroman",
  "font.size": 16,
})
plt.rcParams['figure.figsize'] = (8,6)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
#from mpl_toolkits.mplot3d import Axes3D
dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq20fs\\"
#dir="D:\\doc\\data\\ion1testold\\t500t840\\44\\"
#dir='D:\\doc\\data\\ion1testold\\NoAlignment\\41\\'
#dir="D:\\doc\\data\\ion1testold\\polardis\\"
print('Working directory',dir)
print("\n")
f=open(dir+"alog.dat",encoding="utf-8")
print(f.read(1500))


levels=990
figureDPI=600
figureType="jpeg"

timeUnit="fs"
# Out:
# Working directory D:\doc\data\ion1testold\DifferentDelatTimeOfPumpAndProbe\dteq20fs\
#
#
#  The calculation starts at   0.0000000000000000      femtoseconds and ends at   200.05000298097730      femtoseconds
#  |----- Quantization parameter -----|
#          nr=       128       nj=        60     trux=        15       nn=       900       dt=   0.05000   fs
#       ntmax=      4001     xmin=   1.75000     xmax=  20.00000       dx=   0.14258
#  |-----  Molecular parameters  -----|
#    LiH: Reduced mass=   1604.3258056640625      a.u.Rotation coefficient=   7.5100002288818359      1/cm
#  nr         128 nj          60 trux          15 nn         900
#  dt=   5.0000000745058067E-002 fs
#  rota =   7.5100002288818359      1/cm
#  Calculated time boundary at   0.0000000000000000      ps
#  Absorbing boundary   1.0000000000000000      :   19.500000000000000
#  Set pulses data by set_pulse.in
#  |----- Laser pulse parameters -----|
#  |----- Laser pulse parameters -----|
#        E-feild(V/m)       Freqceny(cm)    Center_time(ps)           FWHM(ps)          Phase(pi)
#      0.00000000E+00         0.00000000        -0.60000000         0.27900000         0.00000000
#      0.90000000E+10     29265.00000000         0.02000000         0.01000000         0.00000000
#      0.30000000E+11     43000.00000000         0.04000000         0.01000000         0.00000000
#  Set special P_L and write the data in "lengdre.dat"
#  The upper limit of the number of quantum rotations
#  at the initial moment is  2
#  The temperature of the system is   5.0 K
#  The max of J of   5.0  K, is 0.481
#  before scaling initial energy in cm-1

# %%
plt.figure(figsize=(16,24))
titleLoc="left"
dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq20fs\\"

plt.subplot(4,2,1)
DataAng =np.loadtxt(dir+"Exc_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
plt.title("(a)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,2)
DataAng =np.loadtxt(dir+"Ion_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(e)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")

dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq40fs\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,3)
DataAng =np.loadtxt(dir+"Exc_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
plt.title("(b)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,4)
DataAng =np.loadtxt(dir+"Ion_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(f)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")

dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq60fs\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,5)
DataAng =np.loadtxt(dir+"Exc_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
plt.title("(c)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,6)
DataAng =np.loadtxt(dir+"Ion_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(g)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")


dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq80fs\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,7)
DataAng =np.loadtxt(dir+"Exc_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
plt.title("(d)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,8)
DataAng =np.loadtxt(dir+"Ion_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(h)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")

plt.savefig(dir+"ExcIonRad."+figureType,bbox_inches="tight",transparent=True,dpi=figureDPI)

# %%
os.startfile(dir)
