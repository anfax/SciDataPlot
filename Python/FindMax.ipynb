# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import os
plt.rcParams['ytick.right']  =plt.rcParams['xtick.top'] =True
xminorLocator=MultipleLocator(2)
#plt.rcParams['set_minor_locator']=xminorLocator
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Time New Rroman"]})
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    #"font.serif": ["Palatino"],
    "font.serif": ["Time New Roman"], 
})
# It's also possible to use the reduced notation by directly setting font.family:
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "Time New Roman",
  "font.size": 8,
})

def cm_to_inch(value):
    return value/2.54

plt.rcParams['figure.figsize'] = (cm_to_inch(8), cm_to_inch(6.5))
#plt.rcParams['figure.figsize'] =(4,3)#(3.5,2.5)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
from mpl_toolkits.mplot3d import Axes3D
dir='D:\\doc\\data\\ori\\35\\'
print('Working directory',dir)
print("\n")
f=open(dir+"alog.dat",encoding="utf-8")
print(f.read(1500))
levels=100
figureDPI=1200
figureType="jpeg"
timeUnit="fs"
f=open(dir+"alog.dat",encoding="utf-8")
print(f.read())
import os
os.startfile(dir)

# %%
plt.figure(figsize=(8,6))
for ii in (0,5,15,25,35):
    dataw=np.loadtxt("D:\\"+str(ii)+"K.txt")
    w=dataw[:,1]
    f=open(dir+'TmpTimOri'+str(ii)+'K.dat','w')

    for i in range(0,81,1):
        #i=400
        #print(i)
        #print(w[0])
        data=np.loadtxt(dir+str(i*50+500)+"\\cos1s.dat")
        x1=data[:,0]
        y1=data[:,1]
        y2=data[:,2]
        y3=data[:,3]
        y4=data[:,4]
        y5=data[:,5]
        y6=data[:,6]
        y7=data[:,7]
        y8=data[:,8]
        x=x1
        y=y1*w[0]+y2*w[1]+y3*w[2]+y4*w[3]+y5*w[4]+y6*w[5]+y7*w[6]+y8*w[7]
        # for j in range(0,len(x),1):
        #     print(j)
        
        f.write(str(i*50+500)+"  "+str(max(y[150:]))+"  "+str(min(y[150:]))+"\n")
        #plt.plot(x,y)    
    f.close()
    data=np.loadtxt(dir+"TmpTimOri"+str(ii)+"K.dat")
    x=data[:,0]
    y=data[:,1]
    z=data[:,2]
    plt.plot(x,y,x,z)
    plt.xlabel("Delay time (fs)")
    plt.legend(["0 K","5 K","15 K","25 K","35 K"])
    plt.ylabel("$\\langle cos \\theta \\rangle$")

# %%
data=np.loadtxt(dir+"TmpTimOri35K.dat")
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.plot(x,y,x,z)
#plt.tricontourf(x,y,z)

# %%
plt.figure(figsize=(24,18))
for ii in (0,5,15,25,35):
    dataw=np.loadtxt("D:\\"+str(ii)+"K.txt")
    w=dataw[:,1]
    for i in range(500,5000,50):
        data=np.loadtxt(dir+str(i)+"\\cos1s.dat")
        x1=data[:,0]
        y1=data[:,1]
        y2=data[:,2]
        y3=data[:,3]
        y4=data[:,4]
        y5=data[:,5]
        y6=data[:,6]
        y7=data[:,7]
        y8=data[:,8]
        x=x1
        y=y1*w[0]+y2*w[1]+y3*w[2]+y4*w[3]+y5*w[4]+y6*w[5]+y7*w[6]+y8*w[7]
        plt.plot(x,y)

# %%
plt.figure(figsize=(8,6))
for ii in (0,5,15,25,35):
    dataw=np.loadtxt("D:\\"+str(ii)+"K.txt")
    w=dataw[:,1]
    f=open(dir+'Tmp2700Ori'+str(ii)+'K.dat','w')

    
    i=19
    print(i,i*50+500)
    
    #print(w[0])
    data=np.loadtxt(dir+str(i*50+500)+"\\cos1s.dat")
    x1=data[:,0]
    y1=data[:,1]
    y2=data[:,2]
    y3=data[:,3]
    y4=data[:,4]
    y5=data[:,5]
    y6=data[:,6]
    y7=data[:,7]
    y8=data[:,8]
    x=x1
    y=y1*w[0]+y2*w[1]+y3*w[2]+y4*w[3]+y5*w[4]+y6*w[5]+y7*w[6]+y8*w[7]
    # for j in range(0,len(x),1):
    #     print(j)
    for j in range(0,len(x),1):        
        f.write("  "+str(x[j])+"  "+str(y[j])+"\n")
    plt.plot(x,y)    
    f.close()

# %%
   data=np.loadtxt(dir+"Tmp2700Ori"+str(ii)+"K.dat")
    x=data[:,0]
    y=data[:,1]
    z=data[:,2]
    plt.plot(x,y,x,z)
    plt.xlabel("Delay time (fs)")
    plt.legend(["0 K","5 K","15 K","25 K","35 K"])
    plt.ylabel("$\\langle cos \\theta \\rangle$")

# %%
j=0
dataw=np.loadtxt("D:\\K.txt")
dir='D:\\doc\\data\\ori\\35\\'
f=open(dir+'TmpTimOri.dat','w')
for ii in range(0,1000,1):
    T=ii*0.1
    #dataw=np.loadtxt("D:\\"+str(ii)+"K.txt")
    print("T = ",T)
    for k in range(0,9,1):
        w[k]=dataw[k+j*9,2]
        print(k,w[k])
    j=j+1
   

    for i in range(0,81,1):
        #i=400
        #print(i)
        #print(w[0])
        data=np.loadtxt(dir+str(i*50+500)+"\\cos1s.dat")
        x1=data[:,0]
        y1=data[:,1]
        y2=data[:,2]
        y3=data[:,3]
        y4=data[:,4]
        y5=data[:,5]
        y6=data[:,6]
        y7=data[:,7]
        y8=data[:,8]
        x=x1
        y=y1*w[0]+y2*w[1]+y3*w[2]+y4*w[3]+y5*w[4]+y6*w[5]+y7*w[6]+y8*w[7]
        # for j in range(0,len(x),1):
        #     print(j)
        oMax=max(y[150:])
        oMin=min(y[150:])
        f.write(str(round(T,5))+"  "+str(i*50+500)+"  "+str(round(max(y[150:]),5))+"  "+str(round(min(y[150:]),5))+"\n")
        #plt.plot(x,y)    
f.close()

# %%
plt.figure(figsize=(16/2.54,13/2.54))
data=np.loadtxt(dir+"TmpTimOri.dat")
x=data[:,0]
y=data[:,1]
z1=data[:,2]
z2=data[:,3]
s1=plt.subplot(1,2,1)
plt.title('(a)',loc='left')
plt.tricontourf(x,y,z1,100,cmap='jet')
plt.ylabel("Delay time (fs)")
plt.xlabel("$T$ (K)")
plt.colorbar()
s2=plt.subplot(1,2,2)
plt.title('(b)',loc='left')
plt.tricontourf(x,y,z2,100,cmap='jet')
plt.ylabel("Delay time (fs)")
plt.xlabel("$T$ (K)")
plt.colorbar()
#(s1,s2).colorbar() 
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
plt.savefig(dir+"TmpTimOri."+figureType,bbox_inches = 'tight',dpi=figureDPI)
plt.show()

# %%
plt.figure(figsize=(16/2.54,13/2.54))
data=np.loadtxt(dir+"TmpTimOri.dat")
x=data[:,0]
y=data[:,1]
z1=data[:,2]
z2=data[:,3]
fig,axes=plt.subplots(nrows=1,ncols=2)


a=fig.tricontourf(x,y,z1,100,cmap='rainbow')
plt.ylabel("Delay time (fs)")
plt.xlabel("$T$ (K)")
#plt.colorbar()

b=fig.tricontourf(x,y,z2,100,cmap='jet')
plt.ylabel("Delay time (fs)")
plt.xlabel("$T$ (K)")
#plt.colorbar()
#(s1,s2).colorbar()

fig.colorbar([a,b],ax=[ax,bx],shrink=0.5)  
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
