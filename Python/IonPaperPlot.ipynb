# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import os
plt.rcParams['ytick.right']  =plt.rcParams['xtick.top'] =True
xminorLocator=MultipleLocator(2)
#plt.rcParams['set_minor_locator']=xminorLocator
# It's also possible to use the reduced notation by directly setting font.family:
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "Time New Roman",
  "font.size": 8,
})

def cm2inch(value):
    return value/2.54

plt.rcParams['figure.figsize'] = (cm2inch(8), cm2inch(6.5))
#plt.rcParams['figure.figsize'] =(4,3)#(3.5,2.5)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
from mpl_toolkits.mplot3d import Axes3D

levels=100
figureDPI=1200
figureType="jpeg"
timeUnit="fs"
dir='D:\\doc\\data\\ion\\'
os.mkdir('D:\\doc\\data\\ion\\data')
os.mkdir('D:\\doc\\data\\ion\\picture')

# %%
intDir="D:\\doc\\data\\ion\\molecularData\\"
if os.path.exists(intDir+'pott.dat'):
    data=np.loadtxt(intDir+"Pott.dat")
else:
    data=np.loadtxt(intDir+"PotentialEnergy.dat")
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=data[:,3]
plt.xlabel("$\t{R}$ (a.u.) ")
plt.ylabel("Energy (a.u.)")
plt.plot(x,y1,'k-',x,y2,'r-.',x,y3,'--')
plt.ylim(-0.05,0.5)
plt.xlim(1.75,11)
plt.fill_between(x,y3,x,y3+0.2)
plt.legend(['$X^1\Sigma^+$','$A^1 \Sigma ^+$','$X^2 \Sigma ^+$'],loc=(0.65,0.7))
plt.savefig(dir+"picture\\f1pott."+figureType,bbox_inches="tight",transparent=True,dpi=figureDPI)
np.savetxt(dir+"data\\f1pott.dat",data,fmt="%.9f")

# %%
plt.figure(figsize=(16/2.54,13/2.54))
plt.subplot(2,2,1)
data=np.loadtxt("D:\\doc\\data\\ion1test\\alilong\\laser.dat")
x=data[:,0]
y=data[:,1]
plt.xlim(0,5000)
plt.plot(x,y,'k')
plt.xlabel('Time (fs)')
plt.ylabel('Intensity (V/m)')
plt.title('(a)',loc='right')
np.savetxt(dir+"data\\f2(12).dat",data,fmt="%.9f")
plt.subplot(2,2,3)
data=np.loadtxt("D:\\doc\\data\\ion1test\\alilong\\OrientationAndAlignment.dat")
np.savetxt(dir+"data\\f2(3).dat",data,fmt="%.9f")
x=data[:,0]
y=data[:,2]
plt.xlim(0,5000)
plt.plot(x,y,'k')
plt.title('(c)',loc='right')
plt.xlabel('Time (fs)')
plt.ylabel('$\\langle\\rm{cos^2}\\theta\\rangle$')
plt.subplot(2,2,2)
plt.title('(b)',loc='right')
x=[0,1,2,3,4,5]
y=[ 0.21807067543956959,0.58789061452344060,0.17765944533726921,1.5804301297742095E-002, 4.9711941976089170E-004,5.4991865364745232E-006]
plt.bar(x, y)
plt.xlabel('Rotational quantum number $J$')
plt.ylabel('Population')
plt.xticks([0,1,2,3,4,5])
plt.subplot(2,2,4)
plt.title('(d)',loc='right')
data=np.loadtxt("D:\\doc\\data\\ion1test\\alilong\\GroAngWave.dat")
np.savetxt(dir+"data\\f2(4).dat",data,fmt="%.9f")
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.xlim(min(x),5000)
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
plt.savefig(dir+'picture\\f2.'+figureType,bbox_inches ='tight',dpi=figureDPI)

# %%
intDir="D:\\doc\\data\\ion\\laserData\\"
legengLoc=(0.15,0.75)
plt.figure(figsize=((16/2.54),(13/2)))
#plt.figure(figsize=(8,6))
titleLoc="left"
plt.subplot(2,2,1)
plt.title("(a)",loc=titleLoc)
data=np.loadtxt(intDir+"TimFreDis4.dat")
np.savetxt(dir+"data\\f3(1).dat",data,fmt="%.9f")
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("Frequency (a.u.)")
plt.tricontourf(x,y,z,100,cmap='jet')
#plt.colorbar()
plt.subplot(2,2,2)
plt.title("(b)",loc=titleLoc)
data1=np.loadtxt(intDir+"FreDis1.dat")
data2=np.loadtxt(intDir+"FreDis2.dat")
data3=np.loadtxt(intDir+"FreDis3.dat")
data4=np.loadtxt(intDir+"FreDis4.dat")
np.savetxt(dir+"data\\f3(2).dat",data4,fmt="%.9f")
x1=data1[:,0]
y1=data1[:,1]
x2=data2[:,0]
y2=data2[:,1]
x3=data3[:,0]
y3=data3[:,1]
x4=data4[:,0]
y4=data4[:,1]
plt.xlabel("Intensity (arb.units)") 
plt.ylabel("Frequency (a.u.)")
#plt.xlim(0,5)
plt.ylim(min(np.loadtxt(intDir+"TimFreDis4.dat")[:,1]),max(np.loadtxt(intDir+"TimFreDis4.dat")[:,1]))
# plt.plot(y4,x4)
plt.plot(y1,x1,"k-",y2,x2,"r--")#,y3,x3,'b-.')
#plt.legend(["pump1","pump2","probe"],loc=(0.55,0.7))
plt.legend(["pump","probe"],loc=(0.6,0.1))
#plt.legend(["P 1","P 2","P 3"],loc=legengLoc)
plt.subplot(2,2,3)
data=np.loadtxt(intDir+"Laser.dat")
np.savetxt(dir+"data\\f3(34).dat",data,fmt="%.9f")
x=data[:,0]
y1=data[:,4]
y2=data[:,5]
y3=data[:,6]
plt.xlim(min(x),max(x))
plt.title("(c)",loc=titleLoc)
plt.plot(x,y1,'k-',x,y2,'r--',x,-y1,'k-',x,-y2,'r--',x,y3,'b-.',x,-y3,'b-.')
plt.xlabel("Time (fs)")
plt.ylabel("Intensity (a.u.)")
# plt.legend(["pump1","pump2","probe"],loc=legengLoc)
plt.legend(["pump","probe"],loc=legengLoc)
#plt.legend(["P 1","P 2","P 3"],loc=legengLoc)
plt.subplot(2,2,4)
plt.title("(d)",loc=titleLoc)
data=np.loadtxt(intDir+"Laser.dat")
x1=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=data[:,3]
plt.xlim(min(x),max(x))
plt.xlabel("Time (fs)")
plt.ylabel("Intensity (a.u.)")

plt.plot(x1,y1,'k-',x1,y2,'r-',x,y3,'b-',)
# plt.legend(["pump1","pump2",'probe'],loc=legengLoc)
plt.legend(["pump","probe"],loc=legengLoc)
#plt.legend(["P 1","P 2","P 3"],loc=legengLoc)
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.22)
plt.savefig(dir+"f3TimeFrequencyDistribution."+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
data1=np.loadtxt("D:\\doc\\data\\ion1testold\\PreAlign\\pop.dat")
data2=np.loadtxt("D:\\doc\\data\\ori\\oritest1\\cos2s.dat")
x1=data1[:,0]
y1=data1[:,1]
x2=data2[:,0]
y2=data2[:,1]
np.savetxt(dir+"data\\f4(1).dat",data1,fmt="%.9f")
np.savetxt(dir+"data\\f4(2).dat",data2,fmt="%.9f")
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlim([450,3050])
ax1.set_ylim([0.32,0.67])
ax1.set_xlabel('$t$, $t_{\\rm{pa}}$ (fs)')
ax1.set_ylabel('Ionization probability', color=color)
ax1.scatter(x1, y1, color=color,marker=".")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_xlim([450,3050])
ax2.set_ylim([0.32,0.73])
ax2.set_ylabel('$\\langle{\\rm cos^2} \\theta \\rangle$', color=color)  # we already handled the x-label with ax1
ax2.plot(x2, y2,'--', color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig(dir+"f4AliAndPopVSTime."+figureType,bbox_inches = 'tight',dpi=figureDPI)
plt.show()
import os 
os.startfile(dir+"f4AliAndPopVSTime."+figureType)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8*2),cm2inch(6.5*4)))
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(4, 2)
ax = fig.add_subplot(gs[0,0])
data=np.loadtxt('D:\\doc\\data\\ion1test\\Noali\\GroAngWave.dat')
np.savetxt(dir+"data\\f5(1).dat",data,fmt="%.9f")
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(a)",loc='left')
ax = fig.add_subplot(gs[0,1])
data=np.loadtxt('D:\\doc\\data\\ion1test\\all\\GroAngWave.dat')
np.savetxt(dir+"data\\f5(2).dat",data,fmt="%.9f")
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(e)",loc='left')
ax = fig.add_subplot(gs[1, 0])
data1=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\ExcAngWave.dat')
np.savetxt(dir+"data\\f5(3).dat",data1,fmt="%.9f")
data2=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\IonAngWave.dat')
np.savetxt(dir+"data\\f5(4).dat",data2,fmt="%.9f")
x=data1[0:,0]
y=data1[:,1]
z=data1[:,2]+data2[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(b)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)
ax = fig.add_subplot(gs[1, 1])
data1=np.loadtxt('D:\\doc\\data\\ion1test\\All\\ExcAngWave.dat')
np.savetxt(dir+"data\\f5(5).dat",data1,fmt="%.9f")
data2=np.loadtxt('D:\\doc\\data\\ion1test\\All\\IonAngWave.dat')
np.savetxt(dir+"data\\f5(6).dat",data2,fmt="%.9f")
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]+data2[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(f)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)
ax= fig.add_subplot(gs[2,0])
data=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\populationOfState.dat')
np.savetxt(dir+"data\\f5(7).dat",data,fmt="%.9f")
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
plt.plot(x,y1,'k-',x,y2,'r-',x,y3,'b-')
plt.title("(c)",loc='left')
plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax= fig.add_subplot(gs[2,1])
data=np.loadtxt('D:\\doc\\data\\ion1test\\all\\PopulationOfState.dat')
np.savetxt(dir+"data\\f5(8).dat",data,fmt="%.9f")
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
plt.plot(x,y1,'k-',x,y2,'r-',x,y3,'b-')
plt.title("(g)",loc='left')
plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax= fig.add_subplot(gs[3,0])
data=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\timeenergyspctra.dat')
np.savetxt(dir+"data\\f5(9).dat",data,fmt="%.9f")
x=data[-100:-1,1]
#print(x)
y=data[-100:-1,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
# plt.xlim(-5, 5)
plt.ylim(-0.009, 0.15)
plt.plot(x1,y1,'k')
plt.title("(d)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.5*(max(x)-min(x)),0.2*(max(y)-min(y)),'(1+2)-REMPI')
#interpolation='spline16'
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
ax= fig.add_subplot(gs[3,1])
data=np.loadtxt('D:\\doc\\data\\ion1test\\All\\timeenergyspctra.dat')
np.savetxt(dir+"data\\f5(10).dat",data,fmt="%.9f")
x=data[-100:-1,1]
#print(x)
y=data[-100:-1,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
# plt.xlim(-5, 5)
plt.ylim(-0.009, 0.15)
plt.plot(x1,y1,'k')
plt.title("(h)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.5*(max(x)-min(x)),0.2*(max(y)-min(y)),'(1+2)-REMPI')
#interpolation='spline16'
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
plt.savefig(dir+'picture\\f5Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
data=np.loadtxt('D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\pop.dat')
np.savetxt(dir+"data\\f6.dat",data,fmt="%.9f")
from scipy import interpolate
x=data[:,0]
y=data[:,1]
x1=np.arange(10,151,1)
print(len(x1))
# fn=interpolate.interp1d(x,y,kind='nearest')
# fz=interpolate.interp1d(x,y,kind='zero')
# fs=interpolate.interp1d(x,y,kind='slinear')
# fq=interpolate.interp1d(x,y,kind='quadratic')
fc=interpolate.interp1d(x,y,kind='cubic')
#method of kind: nearest, zero, slinear, quadratic,cubic
y1=fc(x1)
# y2=fz(x1)
# y3=fs(x1)
# y4=fq(x1)
#y5=fc(x1)
color='tab:red'
plt.plot(x,y,color=color,marker=".")
color = 'tab:blue'
#plt.plot(x1,y1,'--',color=color,marker=".")#,x1,y2,x1,y3,x1,y4,x1,y5)
#plt.legend(["Origin"])#,"nearest","zero","slinear","quadratic","cubic"])
plt.xlabel("$t_{\\rm{pp}}$ (fs)")
plt.ylabel("Ionization probability")
plt.savefig(dir+"picture\\f6pop."+figureType,bbox_inches="tight",dpi=figureDPI)
# Out:
# 141

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8*2),cm2inch(6.5*2)))
intDir="D:\\doc\\data\\onepump\\onepump200\\"
plt.subplot(2,1,1)
data=np.loadtxt(intDir+"excradwave.dat")
np.savetxt(dir+"data\\f7(1).dat",data,fmt="%.9f")
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$R$ (a.u.)")
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.title("(a)",loc='left')
# plt.xlim(0,150)
plt.ylim(min(y),10)
plt.subplot(2,1,2)
data=np.loadtxt(intDir+'ktot.dat')
np.savetxt(dir+"data\\f7(2).dat",data,fmt="%.9f")
x=data[:,0]
y=data[:,1]
z1=data[:,2]
z2=data[:,3]
z3=data[:,4]
z4=z1+z2+z3

plt.tricontourf(x,y,z2,levels,cmap='jet')
plt.colorbar()
plt.title('(b)',loc='left')
plt.xlabel('Time (fs)')
plt.ylabel('Momentum (arb.units)')
plt.savefig(dir+'f7pumpExcRadWave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
plt.figure(figsize=(16/2.54,24/2.54))
titleLoc="left"
dir="D:\\doc\\data\\ion1test\\delayPumpAndProbe\\21\\"

plt.subplot(4,2,1)
data =np.loadtxt(dir+"ExcRadWave.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.title("(a)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,2)
data =np.loadtxt(dir+"IonRadWave.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(e)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")

dir="D:\\doc\\data\\ion1test\\delayPumpAndProbe\\42\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,3)
data =np.loadtxt(dir+"ExcRadWave.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.title("(b)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,4)
data =np.loadtxt(dir+"IonRadWave.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(f)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")

dir="D:\\doc\\data\\ion1test\\delayPumpAndProbe\\63\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,5)
data =np.loadtxt(dir+"ExcRadWave.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.title("(c)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,6)
data =np.loadtxt(dir+"IonRadWave.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(g)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")


dir="D:\\doc\\data\\ion1test\\delayPumpAndProbe\\84\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,7)
data =np.loadtxt(dir+"ExcRadWave.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.title("(d)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,8)
data =np.loadtxt(dir+"IonRadWave.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(h)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.25, 
                    hspace=0.35)
dir='D:\\doc\\data\\ion\\'
plt.savefig(dir+"f8ExcIonRad."+figureType,bbox_inches="tight",transparent=True,dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8*2),cm2inch(6.5*4)))
import matplotlib.gridspec as gridspec
subdir="D:\\doc\\data\\ion1test\\delayPumpAndProbe\\"
gs = gridspec.GridSpec(4, 2)
ax = fig.add_subplot(gs[0,0])
data=np.loadtxt(subdir+'21\\populationofstate.dat')
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
print('$P_{ion}$ = ',y3[-1])
plt.plot(x,y1,'k-',x,y2,'r--',x,y3,'b-.')
plt.title("(a)",loc='left')
# plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax = fig.add_subplot(gs[1,0])
data=np.loadtxt(subdir+'42\\populationofstate.dat')
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
print('$P_{ion}$ = ',y3[-1])
plt.plot(x,y1,'k-',x,y2,'r--',x,y3,'b-.')
plt.title("(b)",loc='left')
# plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax = fig.add_subplot(gs[2, 0])
data=np.loadtxt(subdir+'63\\populationofstate.dat')
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
print('$P_{ion}$ = ',y3[-1])
plt.plot(x,y1,'k-',x,y2,'r--',x,y3,'b-.')
plt.title("(c)",loc='left')
#plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax = fig.add_subplot(gs[3,0])
data=np.loadtxt(subdir+'84\\populationofstate.dat')
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
print('$P_{ion}$ = ',y3[-1])
plt.plot(x,y1,'k-',x,y2,'r--',x,y3,'b-.')
plt.title("(d)",loc='left')
#plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax= fig.add_subplot(gs[0,1])
data=np.loadtxt(subdir+'21\\timeenergyspctra.dat')
l=np.argmax(data[:,2])
x=data[l-10:l+90,1]
print(l)
y=data[l-10:l+90,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(-0.009, 0.12)
plt.plot(x1,y1,'k')
plt.title("(e)",loc='left')
#plt.text(0.3*(max(x)-min(x)),0.5*(max(y)-min(y)),'(0+2)-REMPI')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.6*(max(x)-min(x)),0.1*(max(y)-min(y)),'(1+2)-REMPI')
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
ax= fig.add_subplot(gs[1,1])
data=np.loadtxt(subdir+'42\\timeenergyspctra.dat')
l=np.argmax(data[:,2])
x=data[l-10:l+90,1]
print(l)
y=data[l-10:l+90,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(-0.009, 0.12)
plt.plot(x1,y1,'k')
plt.title("(f)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.9*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.6*(max(x)-min(x)),0.6*(max(y)-min(y)),'(1+2)-REMPI')
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
ax= fig.add_subplot(gs[2,1])
data=np.loadtxt(subdir+'63\\timeenergyspctra.dat')
l=np.argmax(data[:,2])
x=data[l-10:l+90,1]
print(l)
y=data[l-10:l+90,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(-0.009, 0.12)
plt.plot(x1,y1,'k')
plt.title("(g)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.6*(max(x)-min(x)),0.2*(max(y)-min(y)),'(1+2)-REMPI')
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
ax= fig.add_subplot(gs[3,1])
data=np.loadtxt(subdir+'84\\timeenergyspctra.dat')
l=np.argmax(data[:,2])
x=data[l-10:l+90,1]
print(l)
y=data[l-10:l+90,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(-0.009, 0.12)
plt.plot(x1,y1,'k')
plt.title("(h)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.6*(max(x)-min(x)),0.3*(max(y)-min(y)),'(1+2)-REMPI')
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
plt.savefig(dir+'f9popenetgy.'+figureType,bbox_inches = 'tight',dpi=figureDPI)
# Out:
# $P_{ion}$ =  0.49409711999999995
# $P_{ion}$ =  0.5113506200000001
# $P_{ion}$ =  0.48937689
# $P_{ion}$ =  0.24266381000000004
# 49007
# 74111
# 99508
# 122709

# %%
data1=np.loadtxt("D:\\doc\\data\\ion1testold\\PreAlign\\poperror.dat")
data2=np.loadtxt('D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\pop.dat')
x1=data1[:,0]
y1=data1[:,1]
x2=data2[:,0]
y2=data2[:,1]
x=np.zeros((26*15))
y=np.zeros((26*15))
z=np.zeros((26*15))

print(len(x2))
print(len(x1))
for i in range(0,26,1):
    for j in range(0,15,1):
        x[i*15+j]=x1[i]
        y[i*15+j]=x2[j]
        z[i*15+j]=y1[i]*y2[j]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlim(500,3000)
plt.ylim(20,150)
plt.xlabel("$t_{\\rm{pa}}$")
plt.ylabel("$t_{\\rm{pp}}$")
plt.savefig(dir+"ttdis."+figureType,bbox_inches="tight",transparent=True,dpi=figureDPI)
# Out:
# 15
# 26

# %%
os.startfile(dir)

# %%
plt.figure(figsize=(16/2.54,6.5/2.54))

plt.subplot(1,2,1)
data =np.loadtxt("D:\\doc\\data\\ion1test\\all\\timeenergyspctra.dat")
#DataAng=scipy.ndimage.zoom(DataAng,1)
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
# plt.xlim(-5, 5)
# plt.ylim(-5, 5)
ax=plt.tricontourf(x,y,z,levels,cmap='jet')

#interpolation='spline16'
plt.colorbar()
plt.xlabel("$t$ ("+timeUnit+")")
plt.ylabel("Energy (eV)")
plt.subplot(1,2,2)
DataAng =np.loadtxt("D:\\doc\\data\\ion1test\\all\\timeenergyspctra.dat")
#DataAng=scipy.ndimage.zoom(DataAng,1)
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[-100:-1,1]
#print(x)
y=DataAng[-100:-1,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(0,10)
#plt.xlim(-0.009, 0.1)
plt.plot(y1,x1,'k')
plt.text(0.2*(max(y)-min(y)),0.6*(max(x)-min(x)),'(1+2)-REMPI')
plt.text(0.5*(max(y)-min(y)),0.2*(max(x)-min(x)),'(1+1)-REMPI')
#interpolation='spline16'
plt.ylabel("Energy (eV)")
plt.xlabel("Intensity (arb.units)")
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
plt.savefig(dir+"timeenergyspctraplustimeend."+figureType,bbox_inches = 'tight',transparent=True,dpi=figureDPI)
plt.show()

# %%
subdir='D:\\doc\\data\\ion1test\\delayPumpAndProbe\\'
plt.figure(figsize=(8*2/2.54,6.5*2/2.54))
plt.subplot(2,2,1)
data1=np.loadtxt(subdir+'21\\ExcRadWave.dat')
data2=np.loadtxt(subdir+'21\\ionRadWave.dat')
x=data1[:,0]*1000
y=data1[:,1]
z=data2[:,2]
plt.xlabel('Time (fs)')
plt.ylabel('$R$ (a.u.)')
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar() 
plt.ylim(min(y),10)
plt.title("(a)",loc='left')

plt.subplot(2,2,2)
data1=np.loadtxt(subdir+'42\\excradwave.dat')
data2=np.loadtxt(subdir+'42\\ionradwave.dat')
x=data1[:,0]
y=data1[:,1]
z=data2[:,2]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.xlabel('Time (fs)')
plt.ylabel('$R$ (a.u.)')
plt.colorbar() 
plt.ylim(min(y),10)
plt.title("(b)",loc='left')

plt.subplot(2,2,3)
data1=np.loadtxt(subdir+'63\\excRadWave.dat')
data2=np.loadtxt(subdir+'63\\ionRadWave.dat')
x=data1[:,0]*1000
y=data1[:,1]
z=data2[:,2]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.xlabel('Time (fs)')
plt.ylabel('$R$ (a.u.)')
plt.colorbar() 
plt.ylim(min(y),10)
plt.title("(c)",loc='left')

plt.subplot(2,2,4)
data1=np.loadtxt(subdir+'84\\excRadWave.dat')
data2=np.loadtxt(subdir+'84\\ionRadWave.dat')
x=data1[:,0]*1000
y=data1[:,1]
z=data2[:,2]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.xlabel('Time (fs)')
plt.ylabel('$R$ (a.u.)')
plt.colorbar() 
plt.ylim(min(y),10)
plt.title("(d)",loc='left')
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
plt.savefig(dir+'ionRadWave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
p=np.zeros((24))

dt=np.zeros((24))
for i in range(0,24,1):
    data=np.loadtxt('D:\\doc\\data\\ion1test\\delayPumpAndProbe\\'+str(i*10+100)+'\\populationOfState.dat')
    p[i]=data[-1,3]
    dt[i]=i*10+100
    print(dt[i],p[i])
plt.scatter(dt,p,10,color='darkred',marker='o')
plt.ylim(0,1)
plt.plot(dt,p,color='grey',marker='+')#,marker='1')
# Out:
# 100.0 0.4795872
# 110.0 0.53673758
# 120.0 0.53672813
# 130.0 0.53710258
# 140.0 0.54171234
# 150.0 0.49441749
# 160.0 0.33365934
# 170.0 0.29789666
# 180.0 0.45662348
# 190.0 0.54387976
# 200.0 0.55434221
# 210.0 0.55141049
# 220.0 0.55583489
# 230.0 0.5437494
# 240.0 0.43697608
# 250.0 0.31328224
# 260.0 0.41915509
# 270.0 0.53721324
# 280.0 0.56153934
# 290.0 0.55993227
# 300.0 0.56150157
# 310.0 0.55973281
# 320.0 0.51082569
# 330.0 0.36851189

# %%
plt.scatter(dt,p,10,color='darkred',marker='o')
plt.ylim(0,1)
plt.plot(dt,p,color='grey',marker='+')

# %%
p=np.zeros((24))
dt=np.zeros((24))
titleLoc='left'
plt.figure(figsize=(16/2.54,13/2.54))
for i in range(0,24,1):
    data1=np.loadtxt('D:\\doc\\data\\ion1test\\delayPumpAndProbe\\'+str(i*10+100)+'\\Excradwave.dat')
    data2=np.loadtxt('D:\\doc\\data\\ion1test\\delayPumpAndProbe\\'+str(i*10+100)+'\\Ionradwave.dat')
    plt.subplot(2,1,1)
    x=data1[:,0]
    y=data1[:,1]
    z=data1[:,2]
    plt.title("(a) $t_{\\rm{pp}} = $"+str(i*10+100)+timeUnit,loc=titleLoc)
    #plt.xlim(TimeTurn,TimeEnd)
    plt.ylim(1.75,10.0)
    plt.tricontourf(x,y,z,levels,cmap='jet')
    plt.colorbar()
    plt.xlabel("Time ("+timeUnit+")")
    plt.ylabel("$R$ (a.u.)")
    plt.subplot(2,1,2)
    x=data2[:,0]
    y=data2[:,1]
    z=data2[:,2]
    plt.title("(b)",loc=titleLoc)
    #plt.xlim(TimeTurn,TimeEnd)
    plt.ylim(1.75,10.0)
    plt.tricontourf(x,y,z,levels,cmap='jet')
    plt.colorbar()
    plt.xlabel("Time ("+timeUnit+")")
    plt.ylabel("$R$ (a.u.)")
    
    plt.savefig(dir+'ExcIonradWave'+str(i*10+100)+'.'+figureType,bbox_inches='tight',dpi=figureDPI)

# %%
fileList =os.listdir(dir)
print(fileList)
image_list=list()
print("Checking image list")
n=len(fileList)
for i in range(n):
    s=dir+str(fileList[i])
    if s[-6:]=="0.jpeg":
        image_list.append(s)
        
import  imageio    
print(image_list)
myduration=eval(input("duration: s"))
frames=[]
gif_name=dir+"waveRad.gif"
for image_name in image_list:
    frames.append(imageio.imread(image_name))
imageio.mimsave(gif_name,frames,'GIF',duration=myduration)
# Out:
# ['ExcIonradWave100.jpeg', 'ExcIonradWave110.jpeg', 'ExcIonradWave120.jpeg', 'ExcIonradWave130.jpeg', 'ExcIonradWave140.jpeg', 'ExcIonradWave150.jpeg', 'ExcIonradWave160.jpeg', 'ExcIonradWave170.jpeg', 'ExcIonradWave180.jpeg', 'ExcIonradWave190.jpeg', 'ExcIonradWave200.jpeg', 'ExcIonradWave210.jpeg', 'ExcIonradWave220.jpeg', 'ExcIonradWave230.jpeg', 'ExcIonradWave240.jpeg', 'ExcIonradWave250.jpeg', 'ExcIonradWave260.jpeg', 'ExcIonradWave270.jpeg', 'ExcIonradWave280.jpeg', 'ExcIonradWave290.jpeg', 'ExcIonradWave300.jpeg', 'ExcIonradWave310.jpeg', 'ExcIonradWave320.jpeg', 'ExcIonradWave330.jpeg', 'f1pott.eps', 'f1pott.jpeg', 'f2Aliss.eps', 'f2Aliss.jpeg', 'f3TimeFrequencyDistribution.eps', 'f3TimeFrequencyDistribution.jpeg', 'f4AliAndPopVSTime.eps', 'f4AliAndPopVSTime.jpeg', 'f5Wave.eps', 'f5Wave.jpeg', 'f6pop.eps', 'f6pop.jpeg', 'f7pumpExcRadWave.eps', 'f7pumpExcRadWave.jpeg', 'f8ExcIonRad.eps', 'f8ExcIonRad.jpeg', 'f9popenetgy.eps', 'f9popenetgy.jpeg', 'ionRadWave.jpeg', 'laserData', 'molecularData', 'timeenergyspctraplustimeend.jpeg', 'ttdis.eps', 'ttdis.jpeg']
# Checking image list
# ['D:\\doc\\data\\ion\\ExcIonradWave100.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave110.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave120.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave130.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave140.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave150.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave160.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave170.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave180.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave190.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave200.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave210.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave220.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave230.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave240.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave250.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave260.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave270.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave280.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave290.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave300.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave310.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave320.jpeg', 'D:\\doc\\data\\ion\\ExcIonradWave330.jpeg']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11536\1512466381.py:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   frames.append(imageio.imread(image_name))

# %%
# fig = plt.figure(tight_layout=True,figsize=(cm2inch(16),cm2inch(12)))
# data1=np.loadtxt('D:\\doc\\data\\ion1test\\All\\GroAngWave.dat')
# data2=np.loadtxt('D:\\doc\\data\\ion1test\\All\\ExcAngWave.dat')
# data3=np.loadtxt('D:\\doc\\data\\ion1test\\all\\IonAngWave.dat')
# import matplotlib.gridspec as gridspec

# gs = gridspec.GridSpec(2, 2)
# ax = fig.add_subplot(gs[0,:])
# x=data1[:,0]
# y=data1[:,1]
# z=data1[:,2]
# plt.xlabel("Time (fs)")
# plt.ylabel("$\\theta$ (degrees)")
# im=ax.tricontourf(x,y,z,levels,cmap='jet')
# plt.colorbar(im,fraction=0.07,pad=0.02)
# plt.yticks([90,180,270])
# plt.title("(a)",loc='left')
# ax = fig.add_subplot(gs[1, 0])
# x=data2[:,0]
# y=data2[:,1]
# z=data2[:,2]
# plt.xlim(1620,1680)
# plt.yticks([90,180,270])
# im=ax.tricontourf(x,y,z,levels,cmap='jet')
# plt.colorbar(im)
# plt.title("(b)",loc='left')
# plt.xlabel("Time (fs)")
# plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)
# ax = fig.add_subplot(gs[1, 1])
# x=data3[:,0]
# y=data3[:,1]
# z=data3[:,2]
# plt.xlim(1620,1680)
# plt.yticks([90,180,270])
# im=ax.tricontourf(x,y,z,levels,cmap='jet')
# plt.colorbar(im)
# plt.title("(c)",loc='left')
# plt.xlabel("Time (fs)")
# plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)

# plt.savefig(dir+'f4Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(16),cm2inch(19.5)))
data1=np.loadtxt('D:\\doc\\data\\ion1test\\onlyali\\GroAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyAli\\ExcAngWave.dat')
data3=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyAli\\IonAngWave.dat')
data4=np.loadtxt('D:\\doc\\data\\ion1test\\all\\GroAngWave.dat')
data5=np.loadtxt('D:\\doc\\data\\ion1test\\all\\ExcAngWave.dat')
data6=np.loadtxt('D:\\doc\\data\\ion1test\\all\\IonAngWave.dat')    
import matplotlib.gridspec as gridspec

gs = gridspec.GridSpec(3, 2)

ax = fig.add_subplot(gs[0,0])
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(a)",loc='left')
ax = fig.add_subplot(gs[1,0])
x=data2[:,0]
y=data2[:,1]
z=data2[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
plt.xlim(1620,1680)
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(b)",loc='left')
ax = fig.add_subplot(gs[2, 0])
x=data3[:,0]
y=data3[:,1]
z=data3[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(c)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[0, 1])
x=data4[:,0]
y=data4[:,1]
z=data4[:,2]
#plt.xlim(min(x),1620)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(d)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[1, 1])
x=data5[:,0]
y=data5[:,1]
z=data5[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(e)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[2, 1])
x=data6[:,0]
y=data6[:,1]
z=data6[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(f)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)
plt.savefig(dir+'f4Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)
