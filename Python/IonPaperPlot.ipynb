# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import os
plt.rcParams['ytick.right']  =plt.rcParams['xtick.top'] =True
xminorLocator=MultipleLocator(2)
#plt.rcParams['set_minor_locator']=xminorLocator
# It's also possible to use the reduced notation by directly setting font.family:
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "Time New Roman",
  "font.size": 8,
})

def cm2inch(value):
    return value/2.54

plt.rcParams['figure.figsize'] = (cm2inch(8), cm2inch(6.5))
#plt.rcParams['figure.figsize'] =(4,3)#(3.5,2.5)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
from mpl_toolkits.mplot3d import Axes3D

levels=100
figureDPI=1200
figureType="jpeg"
timeUnit="fs"
dir='D:\\doc\\data\\ion\\'

# %%
plt.figure(figsize=(16/2.54,13/2.54))
plt.subplot(2,2,1)
data=np.loadtxt("D:\\doc\\data\\ion1test\\alilong\\laser.dat")
x=data[:,0]
y=data[:,1]
plt.xlim(0,5000)
plt.plot(x,y,'k')
plt.xlabel('Time (fs)')
plt.ylabel('Intensity (V/m)')
plt.title('(a)',loc='right')
plt.subplot(2,2,3)
data=np.loadtxt("D:\\doc\\data\\ion1test\\alilong\\OrientationAndAlignment.dat")
x=data[:,0]
y=data[:,2]
plt.xlim(0,5000)
plt.plot(x,y,'k')
plt.title('(c)',loc='right')
plt.xlabel('Time (fs)')
plt.ylabel('$\\langle\\rm{cos^2}\\theta\\rangle$')
plt.subplot(2,2,2)
plt.title('(b)',loc='right')
x=[0,1,2,3,4,5]
y=[ 0.21807067543956959,0.58789061452344060,0.17765944533726921,1.5804301297742095E-002, 4.9711941976089170E-004,5.4991865364745232E-006]
plt.bar(x, y)
plt.xlabel('Rotational quantum number $J$')
plt.ylabel('Population')
plt.xticks([0,1,2,3,4,5])
plt.subplot(2,2,4)
plt.title('(d)',loc='right')
data=np.loadtxt("D:\\doc\\data\\ion1test\\alilong\\GroAngWave.dat")

x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.xlim(min(x),5000)
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
plt.savefig(dir+'Aliss.'+figureType,bbox_inches ='tight',dpi=figureDPI)

# %%
data1=np.loadtxt("D:\\doc\\data\\ion1testold\\PreAlign\\pop.dat")
data2=np.loadtxt("D:\\doc\\data\\ori\\oritest1\\cos2s.dat")
x1=data1[:,0]
y1=data1[:,1]
x2=data2[:,0]
y2=data2[:,1]
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlim([450,3050])
ax1.set_ylim([0.32,0.67])
ax1.set_xlabel('$t$, $t_{\\rm{pa}}$ (fs)')
ax1.set_ylabel('Ionization probability', color=color)
ax1.scatter(x1, y1, color=color,marker=".")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_xlim([450,3050])
ax2.set_ylim([0.32,0.73])
ax2.set_ylabel('$\\langle{\\rm cos^2} \\theta \\rangle$', color=color)  # we already handled the x-label with ax1
ax2.plot(x2, y2,'--', color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig(dir+"f2AliAndPopVSTime."+figureType,bbox_inches = 'tight',dpi=figureDPI)
plt.show()
import os 
os.startfile(dir+"f2AliAndPopVSTime."+figureType)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8*2),cm2inch(6.5*4)))
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(4, 2)
ax = fig.add_subplot(gs[0,0])
data=np.loadtxt('D:\\doc\\data\\ion1test\\Noali\\GroAngWave.dat')
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(a)",loc='left')
ax = fig.add_subplot(gs[0,1])
data=np.loadtxt('D:\\doc\\data\\ion1test\\all\\GroAngWave.dat')

x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(e)",loc='left')
ax = fig.add_subplot(gs[1, 0])
data1=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\ExcAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\IonAngWave.dat')
x=data1[0:,0]
y=data1[:,1]
z=data1[:,2]+data2[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(b)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)
ax = fig.add_subplot(gs[1, 1])
data1=np.loadtxt('D:\\doc\\data\\ion1test\\All\\ExcAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\All\\IonAngWave.dat')
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]+data2[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(f)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)
ax= fig.add_subplot(gs[2,0])
data=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\populationOfState.dat')
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
plt.plot(x,y1,'k-',x,y2,'r-',x,y3,'b-')
plt.title("(c)",loc='left')
plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax= fig.add_subplot(gs[2,1])
data=np.loadtxt('D:\\doc\\data\\ion1test\\all\\PopulationOfState.dat')
x=data[:,0]
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
plt.plot(x,y1,'k-',x,y2,'r-',x,y3,'b-')
plt.title("(g)",loc='left')
plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax= fig.add_subplot(gs[3,0])
data=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\timeenergyspctra.dat')
x=data[-100:-1,1]
#print(x)
y=data[-100:-1,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
# plt.xlim(-5, 5)
plt.ylim(-0.009, 0.15)
plt.plot(x1,y1,'k')
plt.title("(d)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.5*(max(x)-min(x)),0.2*(max(y)-min(y)),'(1+2)-REMPI')
#interpolation='spline16'
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
ax= fig.add_subplot(gs[3,1])
data=np.loadtxt('D:\\doc\\data\\ion1test\\All\\timeenergyspctra.dat')
x=data[-100:-1,1]
#print(x)
y=data[-100:-1,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
# plt.xlim(-5, 5)
plt.ylim(-0.009, 0.15)
plt.plot(x1,y1,'k')
plt.title("(h)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.5*(max(x)-min(x)),0.2*(max(y)-min(y)),'(1+2)-REMPI')
#interpolation='spline16'
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
plt.savefig(dir+'f3Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(16),cm2inch(12)))
data1=np.loadtxt('D:\\doc\\data\\ion1test\\All\\GroAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\All\\ExcAngWave.dat')
data3=np.loadtxt('D:\\doc\\data\\ion1test\\all\\IonAngWave.dat')
import matplotlib.gridspec as gridspec

gs = gridspec.GridSpec(2, 2)
ax = fig.add_subplot(gs[0,:])
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im,fraction=0.07,pad=0.02)
plt.yticks([90,180,270])
plt.title("(a)",loc='left')
ax = fig.add_subplot(gs[1, 0])
x=data2[:,0]
y=data2[:,1]
z=data2[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(b)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
for tick in ax.get_yticklabels():
    tick.set_rotation(55)
ax = fig.add_subplot(gs[1, 1])
x=data3[:,0]
y=data3[:,1]
z=data3[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(c)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
for tick in ax.get_yticklabels():
    tick.set_rotation(55)

plt.savefig(dir+'f4Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(16),cm2inch(19.5)))
data1=np.loadtxt('D:\\doc\\data\\ion1test\\onlyali\\GroAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyAli\\ExcAngWave.dat')
data3=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyAli\\IonAngWave.dat')
data4=np.loadtxt('D:\\doc\\data\\ion1test\\all\\GroAngWave.dat')
data5=np.loadtxt('D:\\doc\\data\\ion1test\\all\\ExcAngWave.dat')
data6=np.loadtxt('D:\\doc\\data\\ion1test\\all\\IonAngWave.dat')    
import matplotlib.gridspec as gridspec

gs = gridspec.GridSpec(3, 2)

ax = fig.add_subplot(gs[0,0])
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(a)",loc='left')
ax = fig.add_subplot(gs[1,0])
x=data2[:,0]
y=data2[:,1]
z=data2[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
plt.xlim(1620,1680)
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(b)",loc='left')
ax = fig.add_subplot(gs[2, 0])
x=data3[:,0]
y=data3[:,1]
z=data3[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(c)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[0, 1])
x=data4[:,0]
y=data4[:,1]
z=data4[:,2]
#plt.xlim(min(x),1620)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(d)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[1, 1])
x=data5[:,0]
y=data5[:,1]
z=data5[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(e)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[2, 1])
x=data6[:,0]
y=data6[:,1]
z=data6[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(f)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)
plt.savefig(dir+'f4Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
data=np.loadtxt('D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\popduo.dat')
from scipy import interpolate
x=data[:,0]
y=data[:,1]
x1=np.arange(10,151,1)
print(len(x1))
# fn=interpolate.interp1d(x,y,kind='nearest')
# fz=interpolate.interp1d(x,y,kind='zero')
# fs=interpolate.interp1d(x,y,kind='slinear')
# fq=interpolate.interp1d(x,y,kind='quadratic')
fc=interpolate.interp1d(x,y,kind='cubic')
#method of kind: nearest, zero, slinear, quadratic,cubic
y1=fc(x1)
# y2=fz(x1)
# y3=fs(x1)
# y4=fq(x1)
#y5=fc(x1)
color='tab:red'
plt.plot(x,y,color=color,marker=".")
color = 'tab:blue'
#plt.plot(x1,y1,'--',color=color,marker=".")#,x1,y2,x1,y3,x1,y4,x1,y5)
#plt.legend(["Origin"])#,"nearest","zero","slinear","quadratic","cubic"])
plt.xlabel("$t_{\\rm{pp}}$ (fs)")
plt.ylabel("Ionization probability")
plt.savefig(dir+"f4pop."+figureType,bbox_inches="tight",dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8),cm2inch(6.5)))
data=np.loadtxt('D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq150fs\\exc_rad.dat')
x=data[:,0]*1000
y=data[:,1]
z=data[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$R$ (a.u.)")
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()

plt.xlim(0,150)
plt.ylim(min(y),10)
#plt.yticks([90,180,270])
#plt.title("(d) $P_{\\rm{Total}}$",loc='left')
plt.savefig(dir+'pumpExcRadWave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
plt.figure(figsize=(16/2.54,6.5/2.54))

plt.subplot(1,2,1)
data =np.loadtxt("D:\\doc\\data\\ion1test\\all\\timeenergyspctra.dat")
#DataAng=scipy.ndimage.zoom(DataAng,1)
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
# plt.xlim(-5, 5)
# plt.ylim(-5, 5)
ax=plt.tricontourf(x,y,z,levels,cmap='jet')

#interpolation='spline16'
plt.colorbar()
plt.xlabel("$t$ ("+timeUnit+")")
plt.ylabel("Energy (eV)")
plt.subplot(1,2,2)
DataAng =np.loadtxt("D:\\doc\\data\\ion1test\\all\\timeenergyspctra.dat")
#DataAng=scipy.ndimage.zoom(DataAng,1)
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[-100:-1,1]
#print(x)
y=DataAng[-100:-1,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(0,10)
#plt.xlim(-0.009, 0.1)
plt.plot(y1,x1,'k')
plt.text(0.2*(max(y)-min(y)),0.6*(max(x)-min(x)),'(1+2)-REMPI')
plt.text(0.5*(max(y)-min(y)),0.2*(max(x)-min(x)),'(1+1)-REMPI')
#interpolation='spline16'
plt.ylabel("Energy (eV)")
plt.xlabel("Intensity (arb.units)")
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
plt.savefig(dir+"timeenergyspctraplustimeend."+figureType,bbox_inches = 'tight',transparent=True,dpi=figureDPI)
plt.show()

# %%
subdir='D:\\doc\\data\\ion1testold\\wave\\'
plt.figure(figsize=(8*2/2.54,6.5*2/2.54))
plt.subplot(2,2,1)
data1=np.loadtxt(subdir+'21\\exc_rad.dat')
data2=np.loadtxt(subdir+'21\\ion_rad.dat')
x=data1[:,0]*1000
y=data1[:,1]
z=data2[:,2]
plt.xlabel('Time (fs)')
plt.ylabel('$R$ (a.u.)')
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar() 
plt.ylim(min(y),10)
plt.title("(a)",loc='left')

plt.subplot(2,2,2)
data1=np.loadtxt(subdir+'42\\excradwave.dat')
data2=np.loadtxt(subdir+'42\\ionradwave.dat')
x=data1[:,0]
y=data1[:,1]
z=data2[:,2]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.xlabel('Time (fs)')
plt.ylabel('$R$ (a.u.)')
plt.colorbar() 
plt.ylim(min(y),10)
plt.title("(b)",loc='left')

plt.subplot(2,2,3)
data1=np.loadtxt(subdir+'63\\exc_rad.dat')
data2=np.loadtxt(subdir+'63\\ion_rad.dat')
x=data1[:,0]*1000
y=data1[:,1]
z=data2[:,2]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.xlabel('Time (fs)')
plt.ylabel('$R$ (a.u.)')
plt.colorbar() 
plt.ylim(min(y),10)
plt.title("(c)",loc='left')

plt.subplot(2,2,4)
data1=np.loadtxt(subdir+'84\\exc_rad.dat')
data2=np.loadtxt(subdir+'84\\ion_rad.dat')
x=data1[:,0]*1000
y=data1[:,1]
z=data2[:,2]
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.xlabel('Time (fs)')
plt.ylabel('$R$ (a.u.)')
plt.colorbar() 
plt.ylim(min(y),10)
plt.title("(d)",loc='left')
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
plt.savefig(dir+'ionRadWave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8*2),cm2inch(6.5*4)))
import matplotlib.gridspec as gridspec
subdir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\"
gs = gridspec.GridSpec(4, 2)
ax = fig.add_subplot(gs[0,0])
data=np.loadtxt(subdir+'dteq20fs\\popu.dat')
x=data[:,0]*1000
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
print('$P_{ion}$ = ',y3[-1])
plt.plot(x,y1,'k-',x,y2,'r--',x,y3,'b-.')
plt.title("(a)",loc='left')
# plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax = fig.add_subplot(gs[1,0])
data=np.loadtxt(subdir+'dteq40fs\\popu.dat')
x=data[:,0]*1000
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
print('$P_{ion}$ = ',y3[-1])
plt.plot(x,y1,'k-',x,y2,'r--',x,y3,'b-.')
plt.title("(b)",loc='left')
# plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax = fig.add_subplot(gs[2, 0])
data=np.loadtxt(subdir+'dteq60fs\\popu.dat')
x=data[:,0]*1000
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
print('$P_{ion}$ = ',y3[-1])
plt.plot(x,y1,'k-',x,y2,'r--',x,y3,'b-.')
plt.title("(c)",loc='left')
#plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax = fig.add_subplot(gs[3,0])
data=np.loadtxt(subdir+'dteq80fs\\popu.dat')
x=data[:,0]*1000
y1=data[:,1]
y2=data[:,2]
y3=1-y1-y2
print('$P_{ion}$ = ',y3[-1])
plt.plot(x,y1,'k-',x,y2,'r--',x,y3,'b-.')
plt.title("(d)",loc='left')
#plt.xlim(1620,1680)
plt.legend(["Gro","Exc","Ion"],loc=(0.7,0.65))
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("Population")
ax= fig.add_subplot(gs[0,1])
data=np.loadtxt(subdir+'dteq20fs\\timeenergyspctra.dat')
l=int(len(data[:,0])*50/200)
x=data[l:l+100,1]
y=data[l:l+100,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(-0.009, 0.12)
plt.plot(x1,y1,'k')
plt.title("(e)",loc='left')
#plt.text(0.3*(max(x)-min(x)),0.5*(max(y)-min(y)),'(0+2)-REMPI')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.6*(max(x)-min(x)),0.1*(max(y)-min(y)),'(1+2)-REMPI')
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
ax= fig.add_subplot(gs[1,1])
data=np.loadtxt(subdir+'dteq40fs\\timeenergyspctra.dat')
l=int(len(data[:,0])*70/200)
x=data[l:l+100,1]
y=data[l:l+100,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(-0.009, 0.12)
plt.plot(x1,y1,'k')
plt.title("(f)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.9*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.6*(max(x)-min(x)),0.6*(max(y)-min(y)),'(1+2)-REMPI')
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
ax= fig.add_subplot(gs[2,1])
data=np.loadtxt(subdir+'dteq60fs\\timeenergyspctra.dat')
l=int(len(data[:,0])*90/200)
x=data[l:l+100,1]
y=data[l:l+100,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(-0.009, 0.12)
plt.plot(x1,y1,'k')
plt.title("(g)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.6*(max(x)-min(x)),0.2*(max(y)-min(y)),'(1+2)-REMPI')
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
ax= fig.add_subplot(gs[3,1])
data=np.loadtxt(subdir+'dteq80fs\\timeenergyspctra.dat')
l=int(len(data[:,0])*110/200)
x=data[l:l+100,1]
y=data[l:l+100,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(-0.009, 0.12)
plt.plot(x1,y1,'k')
plt.title("(h)",loc='left')
plt.text(0.2*(max(x)-min(x)),0.8*(max(y)-min(y)),'(1+1)-REMPI')
plt.text(0.6*(max(x)-min(x)),0.3*(max(y)-min(y)),'(1+2)-REMPI')
plt.xlabel("Energy (eV)")
plt.ylabel("Intensity (arb.units)")
plt.savefig(dir+'popenetgy.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
plt.figure(figsize=(16,24))
titleLoc="left"
dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq20fs\\"

plt.subplot(4,2,1)
DataAng =np.loadtxt(dir+"Exc_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
plt.title("(a)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,2)
DataAng =np.loadtxt(dir+"Ion_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(e)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")

dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq40fs\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,3)
DataAng =np.loadtxt(dir+"Exc_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
plt.title("(b)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,4)
DataAng =np.loadtxt(dir+"Ion_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(f)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")

dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq60fs\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,5)
DataAng =np.loadtxt(dir+"Exc_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
plt.title("(c)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,6)
DataAng =np.loadtxt(dir+"Ion_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(g)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")


dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq80fs\\"
#plt.figure(figsize=(12,6))
plt.subplot(4,2,7)
DataAng =np.loadtxt(dir+"Exc_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
plt.title("(d)",loc=titleLoc)
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
plt.subplot(4,2,8)
DataAng =np.loadtxt(dir+"Ion_rad.dat")
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[:,0]*1000
y=DataAng[:,1]
z=DataAng[:,2]
#plt.xlim(TimeTurn,TimeEnd)
plt.ylim(1.75,10.0)
plt.title("(h)",loc=titleLoc)
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlabel("Time ("+timeUnit+")")
plt.ylabel("$R$ (a.u.)")
dir='D:\\doc\\data\\ion\\'
plt.savefig(dir+"ExcIonRad."+figureType,bbox_inches="tight",transparent=True,dpi=figureDPI)

# %%
data1=np.loadtxt("D:\\doc\\data\\ion1testold\\PreAlign\\poperror.dat")
data2=np.loadtxt('D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\pop.dat')
x1=data1[:,0]
y1=data1[:,1]
x2=data2[:,0]
y2=data2[:,1]
x=np.zeros((26*15))
y=np.zeros((26*15))
z=np.zeros((26*15))

print(len(x2))
print(len(x1))
for i in range(0,26,1):
    for j in range(0,15,1):
        x[i*15+j]=x1[i]
        y[i*15+j]=x2[j]
        z[i*15+j]=y1[i]*y2[j]

plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlim(500,3000)
plt.ylim(20,150)
plt.xlabel("$t_{\\rm{pa}}$")
plt.ylabel("$t_{\\rm{pp}}$")
plt.savefig(dir+"ttdis."+figureType,bbox_inches="tight",transparent=True,dpi=figureDPI)

# %%
p=np.zeros((24))

dt=np.zeros((24))
for i in range(0,24,1):
    data=np.loadtxt('D:\\doc\\data\\ion1test\\delayPumpAndProbe\\'+str(i*10+100)+'\\populationOfState.dat')
    p[i]=data[-1,3]
    dt[i]=i*10+100
    print(dt[i],p[i])
plt.scatter(dt,p,10,color='darkred',marker='o')
plt.plot(dt,p,color='grey',marker='+')#,marker='1')

# %%
os.startfile(dir)
