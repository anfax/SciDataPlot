# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import os
plt.rcParams['ytick.right']  =plt.rcParams['xtick.top'] =True
xminorLocator=MultipleLocator(2)
#plt.rcParams['set_minor_locator']=xminorLocator
# It's also possible to use the reduced notation by directly setting font.family:
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "Time New Roman",
  "font.size": 8,
})

def cm2inch(value):
    return value/2.54

plt.rcParams['figure.figsize'] = (cm2inch(8), cm2inch(6.5))
#plt.rcParams['figure.figsize'] =(4,3)#(3.5,2.5)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
from mpl_toolkits.mplot3d import Axes3D

levels=100
figureDPI=1200
figureType="jpeg"
timeUnit="fs"
dir='D:\\doc\\data\\ion\\'

# %%
data=np.loadtxt('D:\\doc\\data\\ion1test\\onlyali\\cos1.dat')
x=data[:,0]
y=data[:,2]
plt.plot(x,y)

# %%
data1=np.loadtxt("D:\\doc\\data\\ion1testold\\PreAlign\\pop.dat")
data2=np.loadtxt("D:\\doc\\data\\ori\\oritest1\\cos2s.dat")
x1=data1[:,0]
y1=data1[:,1]
x2=data2[:,0]
y2=data2[:,1]
plt.plot(x2,y2)
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlim([450,3050])
ax1.set_ylim([0.32,0.67])
ax1.set_xlabel('$t$, $t_{\\rm{pa}}$ (fs)')
ax1.set_ylabel('Ionization probability', color=color)
ax1.scatter(x1, y1, color=color,marker=".")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_xlim([450,3050])
ax2.set_ylim([0.32,0.73])
ax2.set_ylabel('$\\langle{\\rm cos^2} \\theta \\rangle$', color=color)  # we already handled the x-label with ax1
ax2.plot(x2, y2,'--', color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig(dir+"f2AliAndPopVSTime."+figureType,bbox_inches = 'tight',dpi=figureDPI)
plt.show()
import os 
os.startfile(dir+"f2AliAndPopVSTime."+figureType)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(16),cm2inch(12)))
data1=np.loadtxt('D:\\doc\\data\\ion1test\\onlyali\\GroAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\ExcAngWave.dat')
data3=np.loadtxt('D:\\doc\\data\\ion1test\\NoAli\\IonAngWave.dat')
data4=np.loadtxt('D:\\doc\\data\\ion1test\\All\\ExcAngWave.dat')
data5=np.loadtxt('D:\\doc\\data\\ion1test\\All\\IonAngWave.dat')
import matplotlib.gridspec as gridspec

gs = gridspec.GridSpec(2, 2)
ax = fig.add_subplot(gs[0,:])
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im,fraction=0.07,pad=0.02)
plt.yticks([90,180,270])
plt.title("(a)",loc='left')
ax = fig.add_subplot(gs[1, 0])
x=data2[:,0]+data3[:,0]
y=data2[:,1]+data3[:,1]
z=data2[:,2]+data3[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(b)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
for tick in ax.get_yticklabels():
    tick.set_rotation(55)
ax = fig.add_subplot(gs[1, 1])
x=data4[:,0]+data5[:,0]
y=data4[:,1]+data5[:,1]
z=data4[:,2]+data5[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(c)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
for tick in ax.get_yticklabels():
    tick.set_rotation(55)

plt.savefig(dir+'f3Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(16),cm2inch(12)))
data1=np.loadtxt('D:\\doc\\data\\ion1test\\All\\GroAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\All\\ExcAngWave.dat')
data3=np.loadtxt('D:\\doc\\data\\ion1test\\all\\IonAngWave.dat')
import matplotlib.gridspec as gridspec

gs = gridspec.GridSpec(2, 2)
ax = fig.add_subplot(gs[0,:])
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im,fraction=0.07,pad=0.02)
plt.yticks([90,180,270])
plt.title("(a)",loc='left')
ax = fig.add_subplot(gs[1, 0])
x=data2[:,0]
y=data2[:,1]
z=data2[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(b)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
for tick in ax.get_yticklabels():
    tick.set_rotation(55)
ax = fig.add_subplot(gs[1, 1])
x=data3[:,0]
y=data3[:,1]
z=data3[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(c)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
for tick in ax.get_yticklabels():
    tick.set_rotation(55)

plt.savefig(dir+'f4Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(16),cm2inch(19.5)))
data1=np.loadtxt('D:\\doc\\data\\ion1test\\onlyali\\GroAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyAli\\ExcAngWave.dat')
data3=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyAli\\IonAngWave.dat')
data4=np.loadtxt('D:\\doc\\data\\ion1test\\all\\GroAngWave.dat')
data5=np.loadtxt('D:\\doc\\data\\ion1test\\all\\ExcAngWave.dat')
data6=np.loadtxt('D:\\doc\\data\\ion1test\\all\\IonAngWave.dat')    
import matplotlib.gridspec as gridspec

gs = gridspec.GridSpec(3, 2)

ax = fig.add_subplot(gs[0,0])
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(a)",loc='left')
ax = fig.add_subplot(gs[1,0])
x=data2[:,0]
y=data2[:,1]
z=data2[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
plt.xlim(1620,1680)
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.yticks([90,180,270])
plt.title("(b)",loc='left')
ax = fig.add_subplot(gs[2, 0])
x=data3[:,0]
y=data3[:,1]
z=data3[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(c)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[0, 1])
x=data4[:,0]
y=data4[:,1]
z=data4[:,2]
#plt.xlim(min(x),1620)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(d)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[1, 1])
x=data5[:,0]
y=data5[:,1]
z=data5[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(e)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
ax = fig.add_subplot(gs[2, 1])
x=data6[:,0]
y=data6[:,1]
z=data6[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(f)",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
# for tick in ax.get_yticklabels():
#     tick.set_rotation(55)
plt.savefig(dir+'f4Wave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
if os.path.exists(dir+"TimFreDis1.dat"):
    plt.figure(figsize=(24/2.54,18/2.54))
    data=np.loadtxt(dir+"Laser.dat")

    x1=data[:,0]
    y1=data[:,1]
    y2=data[:,2]
    y3=data[:,3]

    plt.subplot(3,3,1)
    #plt.grid(False)
    x=x1
    y=y1
    plt.text(min(x)+(max(x)-min(x))*0.95,min(y)+(max(y)-min(y))*0.9,"(a)")
    plt.xlabel('Time ('+timeUnit+')')
    plt.ylabel("Intensity (a.u.)")
    plt.xlim(TimeBegin,TimeEnd)
    plt.plot(x1,y1,'k-')

    plt.subplot(3,3,2)
    dataf=np.loadtxt(dir+"FreDis1.dat")
    x=dataf[:,0]
    y=dataf[:,1]
    #plt.grid(False)
    plt.text(min(x)+(max(x)-min(x))*0.95,min(y)+(max(y)-min(y))*0.9,"(a)")
    plt.xlabel('Frequency (a.u.)')
    plt.ylabel("Intensity (arb.units)")
    plt.plot(x,y,'k-')

    plt.subplot(3,3,3)
    dataf=np.loadtxt(dir+"TimFreDis1.dat")
    x=dataf[:,0]
    y=dataf[:,1]
    z=dataf[:,2]
    plt.tricontourf(x,y,z,levels,cmap='jet')
    plt.colorbar()
    plt.xlabel('Time ('+timeUnit+')')
    plt.ylabel('Frequency (a.u.)')

    plt.subplot(3,3,4)
    #plt.grid(False)
    #plt.title("(b)",loc="left")
    plt.xlabel('Time ('+timeUnit+')')
    plt.ylabel("Intensity (a.u.)")
    plt.xlim(TimeTurn,TimeEnd)
    plt.plot(x1,y2,'r-')
    x=x1
    y=y2
    plt.text(TimeTurn+(TimeEnd-TimeTurn)*0.95,min(y)+(max(y)-min(y))*0.9,"(b)")
    plt.subplot(3,3,5)
    dataf=np.loadtxt(dir+"FreDis2.dat")
    x=dataf[:,0]
    y=dataf[:,1]
    #plt.grid(False)
    plt.text(min(x)+(max(x)-min(x))*0.95,min(y)+(max(y)-min(y))*0.9,"(a)")
    plt.xlabel('Frequency (a.u.)')
    plt.ylabel("Intensity (arb.units)")
    plt.plot(x,y,'r-')

    plt.subplot(3,3,6)
    dataf=np.loadtxt(dir+"TimFreDis2.dat")
    x=dataf[:,0]
    y=dataf[:,1]
    z=dataf[:,2]
    plt.tricontourf(x,y,z,levels,cmap='jet')
    plt.colorbar()
    plt.xlabel('Time ('+timeUnit+')')
    plt.ylabel('Frequency (a.u.)')
    plt.subplot(3,3,7)
    #plt.grid(False)
    x=x1
    y=y3
    plt.text(TimeTurn+(TimeEnd-TimeTurn)*0.95,min(y)+(max(y)-min(y))*0.9,"(c)")

    plt.xlabel('Time ('+timeUnit+')')
    plt.ylabel("Intensity (a.u.)")
    plt.xlim(TimeTurn,TimeEnd)
    plt.plot(x1,y3,'b-')
    plt.subplot(3,3,8)
    dataf=np.loadtxt(dir+"FreDis3.dat")
    x=dataf[:,0]
    y=dataf[:,1]
    #plt.grid(False)
    plt.text(min(x)+(max(x)-min(x))*0.95,min(y)+(max(y)-min(y))*0.9,"(a)")
    plt.xlabel('Frequency (a.u.)')
    plt.ylabel("Intensity (arb.units)")
    plt.plot(x,y,'b-')
    plt.subplot(3,3,9)
    dataf=np.loadtxt(dir+"TimFreDis3.dat")
    x=dataf[:,0]
    y=dataf[:,1]
    z=dataf[:,2]
    plt.xlabel('Time ('+timeUnit+')')
    plt.ylabel('Frequency (a.u.)')
    plt.tricontourf(x,y,z,levels,cmap='jet')
    plt.colorbar()
    plt.savefig(dir+"TimFreDis."+figureType,dpi=figureDPI)

# %%
data=np.loadtxt('D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\pop.dat')
from scipy import interpolate
x=data[:,0]
y=data[:,1]
x1=np.arange(10,151,1)
print(len(x1))
# fn=interpolate.interp1d(x,y,kind='nearest')
# fz=interpolate.interp1d(x,y,kind='zero')
# fs=interpolate.interp1d(x,y,kind='slinear')
# fq=interpolate.interp1d(x,y,kind='quadratic')
fc=interpolate.interp1d(x,y,kind='cubic')
#method of kind: nearest, zero, slinear, quadratic,cubic
y1=fc(x1)
# y2=fz(x1)
# y3=fs(x1)
# y4=fq(x1)
#y5=fc(x1)
color='tab:red'
plt.plot(x,y,color=color,marker=".")
color = 'tab:blue'
#plt.plot(x1,y1,'--',color=color,marker=".")#,x1,y2,x1,y3,x1,y4,x1,y5)
#plt.legend(["Origin"])#,"nearest","zero","slinear","quadratic","cubic"])
plt.xlabel("$t_{\\rm{pp}}$ (fs)")
plt.ylabel("Ionization probability")
plt.savefig(dir+"f4pop."+figureType,bbox_inches="tight",dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8*2),cm2inch(6.5*3)))
data1=np.loadtxt('D:\\doc\\data\\ion1test\\All\\GroAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\All\\ExcAngWave.dat')
data3=np.loadtxt('D:\\doc\\data\\ion1test\\all\\IonAngWave.dat')
data4=np.loadtxt('D:\\doc\\data\\ion1test\\all\\totalangdis.dat')
import matplotlib.gridspec as gridspec

gs = gridspec.GridSpec(3, 2)
ax = fig.add_subplot(gs[0,:])
x=data1[:,0]
y=data1[:,1]
z=data1[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im,fraction=0.07,pad=0.02)
plt.yticks([90,180,270])
plt.title("(a) $P_{\\rm{X}$",loc='left')
ax = fig.add_subplot(gs[1, 0])
x=data2[:,0]
y=data2[:,1]
z=data2[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(b) $P_{\\rm{A}}$",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
for tick in ax.get_yticklabels():
    tick.set_rotation(55)
ax = fig.add_subplot(gs[1, 1])
x=data3[:,0]
y=data3[:,1]
z=data3[:,2]
plt.xlim(1620,1680)
plt.yticks([90,180,270])
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im)
plt.title("(c) $P_{I_{n}}$",loc='left')
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
for tick in ax.get_yticklabels():
    tick.set_rotation(55)
    print('ok')
ax = fig.add_subplot(gs[2,:])
x=data4[:,0]
y=data4[:,1]
z=data4[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
im=ax.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar(im,fraction=0.07,pad=0.02)
plt.yticks([90,180,270])
plt.title("(d) $P_{\\rm{Total}}$",loc='left')
plt.savefig(dir+'ftotalWave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8),cm2inch(6.5)))
data1=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyPump\\GroAngWave.dat')
data2=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyPump\\ExcAngWave.dat')
data3=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyPump\\IonAngWave.dat')
data4=np.loadtxt('D:\\doc\\data\\ion1test\\OnlyPump\\totalangdis.dat')

x=data2[:,0]
y=data2[:,1]
z=data2[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$\\theta$ (degrees)")
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()
plt.xlim(1620,1680)
plt.yticks([90,180,270])
#plt.title("(d) $P_{\\rm{Total}}$",loc='left')
plt.savefig(dir+'pumpExctotalWave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
fig = plt.figure(tight_layout=True,figsize=(cm2inch(8),cm2inch(6.5)))
data=np.loadtxt('D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq150fs\\exc_rad.dat')
x=data[:,0]*1000
y=data[:,1]
z=data[:,2]
plt.xlabel("Time (fs)")
plt.ylabel("$R$ (a.u.)")
plt.tricontourf(x,y,z,levels,cmap='jet')
plt.colorbar()

plt.xlim(0,150)
plt.ylim(min(y),10)
#plt.yticks([90,180,270])
#plt.title("(d) $P_{\\rm{Total}}$",loc='left')
plt.savefig(dir+'pumpExcRadWave.'+figureType,bbox_inches = 'tight',dpi=figureDPI)

# %%
plt.figure(figsize=(16/2.54,6.5/2.54))

plt.subplot(1,2,1)
data =np.loadtxt("D:\\doc\\data\\ion1test\\all\\timeenergyspctra.dat")
#DataAng=scipy.ndimage.zoom(DataAng,1)
#plt.style.use('_mpl-gallery-nogrid')
x=data[:,0]
y=data[:,1]
z=data[:,2]
# plt.xlim(-5, 5)
# plt.ylim(-5, 5)
ax=plt.tricontourf(x,y,z,levels,cmap='jet')

#interpolation='spline16'
plt.colorbar()
plt.xlabel("$t$ ("+timeUnit+")")
plt.ylabel("Energy (eV)")
plt.subplot(1,2,2)
DataAng =np.loadtxt("D:\\doc\\data\\ion1test\\all\\timeenergyspctra.dat")
#DataAng=scipy.ndimage.zoom(DataAng,1)
#plt.style.use('_mpl-gallery-nogrid')
x=DataAng[-100:-1,1]
#print(x)
y=DataAng[-100:-1,2]
x1=np.arange(min(x),max(x),(max(x)-min(x))/200)
from scipy import interpolate
y1=interpolate.interp1d(x,y,kind='cubic')(x1)
plt.ylim(0,10)
plt.xlim(-0.009, 0.1)
plt.plot(y1,x1,'k')
plt.text(0.2*(max(y)-min(y)),0.6*(max(x)-min(x)),'(1+2)-REMPI')
plt.text(0.5*(max(y)-min(y)),0.2*(max(x)-min(x)),'(1+1)-REMPI')
#interpolation='spline16'
plt.ylabel("Energy (eV)")
plt.xlabel("Intensity (arb.units)")
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)
plt.savefig(dir+"timeenergyspctraplustimeend."+figureType,bbox_inches = 'tight',transparent=True,dpi=figureDPI)
plt.show()

# %%
plt.figure(figsize=(cm2inch(8),cm2inch(6.5)))
x= np.arange(0, 2, 0.01)
y=np.sin(x)
plt.plot(x,y)
