# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import os
plt.rcParams['ytick.right']  =plt.rcParams['xtick.top'] =True
xminorLocator=MultipleLocator(2)
#plt.rcParams['set_minor_locator']=xminorLocator

plt.rcParams['figure.figsize'] = (8,6)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
#from mpl_toolkits.mplot3d import Axes3D
#dir="D:\\doc\\data\\ion1testold\\DifferentDelatTimeOfPumpAndProbe\\dteq50fs\\"
#dir="D:\\doc\\data\\ion1testold\\t500t840\\44\\"
#dir='D:\\doc\\data\\ion1testold\\NoAlignment\\41\\'
dir='D:\\doc\\data\\TimeFrequencyDistribution\\tset1\\'
print('Working directory',dir)
print("\n")
levels=100
figureDPI=1200
figureType="jpeg"
timeUnit="fs"
import os
os.startfile(dir)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax1=plt.axes(projection='3d')

data=np.loadtxt(dir+"Laser.dat")
x=data[:,0]
y=data[:,1]
z=data[:,2]
ax1.scatter3D(x,y,z,cmap="Blues",s=0.2,)
plt.plot3d(x,y,z)

# %%
data=np.loadtxt(dir+"BoltzmanInit.dat")
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.axes(projection='3d').scatter3D(x,y,z)

# %%
data=np.loadtxt(dir+"orientation.dat")
x=data[:,0]
y=data[:,1]
plt.xlim(8,12)
plt.plot(x,y)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data
data=np.loadtxt(dir+"BoltzmanInit.dat")
x=data[:,0]
y=data[:,1]
z=data[:,2]
# Plot the surface
#ax.plot_surface(x, y, z, color='b')
ax.plot_surface(x, y, z,cmap='jet')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\github\SciDataPlot\Python\orientation3d.ipynb Cell 5 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/d%3A/github/SciDataPlot/Python/orientation3d.ipynb#ch0000004?line=11'>12</a> z=data[:,2]
#      <a href='vscode-notebook-cell:/d%3A/github/SciDataPlot/Python/orientation3d.ipynb#ch0000004?line=12'>13</a> # Plot the surface
#      <a href='vscode-notebook-cell:/d%3A/github/SciDataPlot/Python/orientation3d.ipynb#ch0000004?line=13'>14</a> #ax.plot_surface(x, y, z, color='b')
# ---> <a href='vscode-notebook-cell:/d%3A/github/SciDataPlot/Python/orientation3d.ipynb#ch0000004?line=14'>15</a> ax.plot_surface(x, y, z,cmap='jet')
#      <a href='vscode-notebook-cell:/d%3A/github/SciDataPlot/Python/orientation3d.ipynb#ch0000004?line=16'>17</a> plt.show()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\_api\deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1581, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1578 had_data = self.has_data()
#    1580 if Z.ndim != 2:
# -> 1581     raise ValueError("Argument Z must be 2-dimensional.")
#    1583 Z = cbook._to_unmasked_float_array(Z)
#    1584 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
DataPop=np.loadtxt(dir+"BoltzmanInit.dat")
x=DataPop[:,0]
y=DataPop[:,1]
z=DataPop[:,2]
ny=int((max(y)-min(y))/(y[2]-y[1]))+1
nx=int((max(x)-min(x))/(x[ny]-x[0]))+1
zMesh=np.zeros((nx,ny))
for i in range(1,nx):
    for j in range(1,ny):
        zMesh[i-1,j-1]=z[*ny+i-1]
print('nx= ',nx,' ny= ',ny)
print('xMax= ',max(x),' xMin= ',min(x),' yMax= ',max(y),' yMin= ',min(y))
print('x[50]',x[50])
print(x[0])
print(zMesh)
xMesh=np.linspace(min(x),max(x),nx)
yMesh=np.linspace(min(y),max(y),ny)
#xx,yy,zz=np.meshgrid(xMesh,yMesh,zMesh)
plt.pcolormesh(xMesh,yMesh,zMesh,cmap='jet')
#plt.ylim(-0.5,5.5)
plt.xlabel('Time ('+timeUnit+')')
plt.ylabel('Vibrational quantum state')
plt.colorbar()

# %%
DataPop=np.loadtxt(dir+"BoltzmanDist.dat")
x=DataPop[:,0]
y=DataPop[:,1]
z=DataPop[:,2]
plt.tricontourf(x,y,z,cmap='jet')
plt.xlim(-0.5,5.5)
plt.xlabel('Time ('+timeUnit+')')
plt.ylabel('Vibrational quantum state')
plt.colorbar()
