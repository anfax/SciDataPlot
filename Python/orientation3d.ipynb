# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import os
from matplotlib import ticker
plt.rcParams['ytick.right']  =plt.rcParams['xtick.top'] =True
xminorLocator=MultipleLocator(2)
#plt.rcParams['set_minor_locator']=xminorLocator
# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "sans-serif",
#     "font.sans-serif": ["Time New Rroman"]})
# # for Palatino and other serif fonts use:
# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "serif",
#     #"font.serif": ["Palatino"],
#     "font.serif": ["Time New Roman"], 
# })
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.rcParams.update({
#   "text.usetex": True,
#   "font.family": "Time New Roman",
#   "font.size": 8,
# })


def cm2inch(value):
    return value/2.54

plt.rcParams['figure.figsize'] = (cm2inch(8), cm2inch(6.5))
#plt.rcParams['figure.figsize'] =(4,3)#(3.5,2.5)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.labelsize'] = 6
plt.rcParams['ytick.labelsize'] = 6
plt.rcParams['legend.fontsize'] =6

from matplotlib import rcParams
config = {
    "text.usetex": False,
    "font.family":'serif',
    # "font.family":'stix',
    "font.size": 8,
    "mathtext.fontset":'stix',
    # "font.serif": ['SimSun'],
}
rcParams.update(config)


from mpl_toolkits.mplot3d import Axes3D
import numpy 
def setlabel(ax, label, loc=2, borderpad=0.6, **kwargs):
    legend = ax.get_legend()
    if legend:
        ax.add_artist(legend)
    line, = ax.plot(numpy.NaN,numpy.NaN,color='none',label=label,fillstyle='full')
    # legend_font = {
    # 'family': 'Times New Roman',
    # 'style':'normal',
    # 'size':10,
    # 'weight': "bold",
    # }
    label_legend = ax.legend(handles=[line],
                             loc=[-0.2,1.0005],
                             handlelength=0.0,
                             handleheight=0.0,
                             handletextpad=0.0,
                             borderaxespad=0.0,
                             borderpad=borderpad,
                             frameon=False,
                             shadow=True,
                             facecolor='gray',
                             prop={'weight':'bold','size':8},
                             **kwargs)
    label_legend.remove()
    ax.add_artist(label_legend)
    line.remove()
def setlabelm(ax, label, loc, borderpad=0.6, **kwargs):
    legend = ax.get_legend()
    if legend:
        ax.add_artist(legend)
    line, = ax.plot(numpy.NaN,numpy.NaN,color='none',label=label)
    label_legend = ax.legend(handles=[line],
                             loc=loc,
                             handlelength=0,
                             handleheight=0,
                             handletextpad=0,
                             borderaxespad=0,
                             borderpad=borderpad,
                             frameon=False,
                             shadow=True,
                             facecolor='gray',
                             prop={'weight':'bold','size':8},
                             **kwargs)
    label_legend.remove()
    ax.add_artist(label_legend)
    line.remove()
def sciformat(ax):
    formatter=ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    formatter.set_powerlimits((0,0))
    ax.yaxis.set_major_formatter(formatter)
levels=100
figureDPI=1200
figureType="jpeg"
timeUnit="fs"
dir='D:\\doc\\data\\ion\\'

# %%
dir='D:\\dataofpro\\'
print('Working directory',dir)
print("\n")

# %%
data1=np.loadtxt(dir+"orientation.dat")
data2=np.loadtxt(dir+"Totalorientation.dat")
x1=data1[:,0]
y1=data1[:,1]
x2=data2[:,0]
y2=data2[:,1]
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Time ('+timeUnit+')')
ax1.set_ylabel('$\\langle{\\rm  cos} \\theta \\rangle$', color=color)
ax1.plot(x1, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)
plt.xlim(5,15)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('$\\langle{\\rm cos^2} \\theta \\rangle$', color=color)  # we already handled the x-label with ax1
ax2.plot(x2, y2,'--', color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig(dir+"OrientationAndAlignment."+figureType,bbox_inches = 'tight',dpi=figureDPI)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
data=np.loadtxt(dir+"BoltzmanInit.dat")
j=data[:,0]
m=data[:,1]
p=data[:,2]
ax.scatter(j,m,p)
plt.xlabel("J")
plt.ylabel("M")
plt.title("Boltzman distributions")
plt.savefig(dir+"BoltzmanInitialDistribuiton."+figureType,bbox_inches = 'tight',dpi=figureDPI)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
data=np.loadtxt(dir+"BoltzmanDist.dat")
print(data)
j=data[:,0]
m=data[:,1]
p=data[:,2]
ax.scatter(j,m,p)
plt.xlabel("J")
plt.ylabel("M")
plt.title("Boltzman distributions")
plt.savefig(dir+"BoltzmanFinalDistribuiton."+figureType,bbox_inches = 'tight',dpi=figureDPI)
plt.show()

# %%
import matplotlib
leg=[]
# plt.figure(figsize=(16,13))
linsty=["-","--","-.",":"]
jmin=2
jmax=2
n=0
for i in range(jmin,jmax+1):
    # if (i == 0):
    #     m=0
    #     data=np.loadtxt(dir+"PopuTot/PopuTotJ"+str(i)+"m"+str(m))
    #     print(i,m)
    #     x=data[:,2]
    #     y=data[:,3]
    #     plt.plot(x,y,'-')
    #     leg=("$\\vert$"+str(i)+","+str(m)+"$\\rangle$")
    #     # plt.legend(leg,ncol=3)
    # else : 
        for m in range(-i,i+1):
            data=np.loadtxt(dir+"PopuTot/PopuTotJ"+str(i)+"m"+str(m))
            print(i,m)
            x=data[:,2]
            y=data[:,3]
            while n == len(linsty):
                n=n-len(linsty)
            plt.plot(x,y,ls=linsty[n])
            leg.append("$\\vert$"+str(i)+","+str(m)+"$\\rangle$")
            # print("leg=",leg)
            n=n+1
    # print("n ",n)
    
plt.xlim(0,25)
plt.legend(leg,ncol=2,fontsize="5")
plt.savefig(dir+"PopuTotOfJEq"+str(jmin)+"To"+str(jmax)+"."+figureType,
            bbox_inches = 'tight',
            dpi=figureDPI)
plt.show()
os.startfile(dir+"PopuTotOfJEq"+str(jmin)+"To"+str(jmax)+"."+figureType)

# %%
import matplotlib

# plt.figure(figsize=(16,13))
linsty=["-","--","-.",":"]
jmin=0
jmax=8
plt.figure(figsize=(8*3/2.54,6.5*3/2.54))
for s in range(jmin,jmax+1):
    n=0
    leg=[]
    plt.subplot(3,3,s+1)
    for i in range(s,s+1):
        # if (i == 0):
        #     m=0
        #     data=np.loadtxt(dir+"PopuTot/PopuTotJ"+str(i)+"m"+str(m))
        #     print(i,m)
        #     x=data[:,2]
        #     y=data[:,3]
        #     plt.plot(x,y,'-')
        #     leg=("$\\vert$"+str(i)+","+str(m)+"$\\rangle$")
        #     # plt.legend(leg,ncol=3)
        # else : 
            for m in range(-i,i+1):
                data=np.loadtxt(dir+"PopuTot/PopuTotJ"+str(i)+"m"+str(m))
                print(i,m)
                x=data[:,2]
                y=data[:,3]
                while n == len(linsty):
                    n=n-len(linsty)
                plt.plot(x,y,ls=linsty[n])
                leg.append("$\\vert$"+str(i)+","+str(m)+"$\\rangle$")
                # print("leg=",leg)
                n=n+1
        # print("n ",n)
    plt.xlim(0,25)
    plt.legend(leg,ncol=2,fontsize="5")
plt.savefig(dir+"PopuTotOfJEq"+str(jmin)+"To"+str(jmax)+"."+figureType,
            bbox_inches = 'tight',
            dpi=figureDPI)
plt.show()

os.startfile(dir+"PopuTotOfJEq"+str(jmin)+"To"+str(jmax)+"."+figureType)
os.startfile(dir)

# %%
data=np.loadtxt(dir+"BoltzmanInit.dat")
j=data[:,0]
m=data[:,1]
p=data[:,2]
for i in range(0,max(j)):
    mmax=(i+1)**2
    for ii in range(0,mmax):

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax1=plt.axes(projection='3d')

data=np.loadtxt(dir+"Laser.dat")
x=data[:,0]
y=data[:,1]
z=data[:,2]
ax1.scatter3D(x,y,z,cmap="Blues",s=0.2,)
# plt.tricontour(x,y,z,levels,cmap="jet")
# plt.plot3d(x,y,z)

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
data=np.loadtxt(dir+"Laser.dat")
x=data[:,0]
y=data[:,1]
z=data[:,2]
# Make data.
X = x
Y = y
X, Y = np.meshgrid(x, y)

Z =z

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
data=np.loadtxt(dir+"BoltzmanInit.dat")
x=data[:,0]
y=data[:,1]
z=data[:,2]
plt.axes(projection='3d').scatter3D(x,y,z)

# %%
data=np.loadtxt(dir+"orientation.dat")
x=data[:,0]
y=data[:,1]
plt.xlim(8,12)
plt.plot(x,y)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data
data=np.loadtxt(dir+"BoltzmanInit.dat")
x=data[:,0]
y=data[:,1]
z=data[:,2]
# Plot the surface
#ax.plot_surface(x, y, z, color='b')
ax.plot_surface(x, y, z,cmap='jet')

plt.show()

# %%
DataPop=np.loadtxt(dir+"BoltzmanInit.dat")
x=DataPop[:,0]
y=DataPop[:,1]
z=DataPop[:,2]
ny=int((max(y)-min(y))/(y[2]-y[1]))+1
nx=int((max(x)-min(x))/(x[ny]-x[0]))+1
zMesh=np.zeros((nx,ny))
for i in range(1,nx):
    for j in range(1,ny):
        zMesh[i-1,j-1]=z[*ny+i-1]
print('nx= ',nx,' ny= ',ny)
print('xMax= ',max(x),' xMin= ',min(x),' yMax= ',max(y),' yMin= ',min(y))
print('x[50]',x[50])
print(x[0])
print(zMesh)
xMesh=np.linspace(min(x),max(x),nx)
yMesh=np.linspace(min(y),max(y),ny)
#xx,yy,zz=np.meshgrid(xMesh,yMesh,zMesh)
plt.pcolormesh(xMesh,yMesh,zMesh,cmap='jet')
#plt.ylim(-0.5,5.5)
plt.xlabel('Time ('+timeUnit+')')
plt.ylabel('Vibrational quantum state')
plt.colorbar()

# %%
DataPop=np.loadtxt(dir+"BoltzmanDist.dat")
x=DataPop[:,0]
y=DataPop[:,1]
z=DataPop[:,2]
plt.tricontourf(x,y,z,cmap='jet')
plt.xlim(-0.5,5.5)
plt.xlabel('Time ('+timeUnit+')')
plt.ylabel('Vibrational quantum state')
plt.colorbar()
